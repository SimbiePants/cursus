# %%
import pandas as pd #http://pandas.pydata.org/pandas-docs/stable/api.html

# %%
cd C:/Users/Syl/Courses/DAT210x-master
# Out:
# C:\Users\Syl\Courses\DAT210x-master

# %%
pwd
# Out:
# 'C:\\Users\\Syl\\Courses\\DAT210x-master'

# %%
data1 = pd.read_csv('C:/Users/Syl/Courses/DAT210x-master/Module2/Datasets/direct_marketing.csv')

# %%
data1.head()
# Out:
#    recency history_segment  history  mens  womens   zip_code  newbie channel  \
# 0       10  2) $100 - $200   142.44     1       0  Surburban       0   Phone
# 1        6  3) $200 - $350   329.08     1       1      Rural       1     Web
# 2        7  2) $100 - $200   180.65     0       1  Surburban       1     Web
# 3        9  5) $500 - $750   675.83     1       0      Rural       1     Web
# 4        2    1) $0 - $100    45.34     1       0      Urban       0     Web
#
#          segment  visit  conversion  spend  DM_category
# 0  Womens E-Mail      0           0    0.0            4
# 1      No E-Mail      0           0    0.0           11
# 2  Womens E-Mail      0           0    0.0            1
# 3    Mens E-Mail      0           0    0.0            2
# 4  Womens E-Mail      0           0    0.0            4

# %%
data1.describe()
# Out:
#             recency       history          mens        womens        newbie  \
# count  64000.000000  64000.000000  64000.000000  64000.000000  64000.000000
# mean       5.763734    242.085656      0.551031      0.549719      0.502250
# std        3.507592    256.158608      0.497393      0.497526      0.499999
# min        1.000000     29.990000      0.000000      0.000000      0.000000
# 25%        2.000000     64.660000      0.000000      0.000000      0.000000
# 50%        6.000000    158.110000      1.000000      1.000000      1.000000
# 75%        9.000000    325.657500      1.000000      1.000000      1.000000
# max       12.000000   3345.930000      1.000000      1.000000      1.000000
#
#               visit    conversion         spend   DM_category
# count  64000.000000  64000.000000  64000.000000  64000.000000
# mean       0.146781      0.009031      1.050908      3.851750
# std        0.353890      0.094604     15.036448      2.131944
# ...

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=64000, step=1)

# %%
data1.dtypes
# Out:
# recency              int64
# history_segment     object
# history            float64
# mens                 int64
# womens               int64
# zip_code            object
# newbie               int64
# channel             object
# segment             object
# visit                int64
# conversion           int64
# spend              float64
# DM_category          int64
# dtype: object

# %%
data1.loc[3:6,'recency'] #returns a series. loc finds labels, so the 6 is included
# Out:
# 3    9
# 4    2
# 5    6
# 6    9
# Name: recency, dtype: int64

# %%
data1.loc[3:6,['recency']] #returns a dataframe. loc finds labels, so the 6 is included
# Out:
#    recency
# 3        9
# 4        2
# 5        6
# 6        9

# %%
data1.iloc[3:6,[0]] #iloc finds indexes, so the 6 is excluded
# Out:
#    recency
# 3        9
# 4        2
# 5        6

# %%
data1.recency < 7 #Boolean indexing
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17       False
# 18       False
# 19        True
# 20       False
# 21       False
# 22        True
# 23        True
# 24        True
# 25        True
# 26       False
# 27        True
# 28       False
# 29        True
#          ...
# 63970     True
# 63971     True
# 63972     True
# 63973    False
# 63974    False
# 63975    False
# 63976     True
# 63977    False
# 63978    False
# 63979    False
# 63980     True
# 63981     True
# 63982     True
# 63983     True
# 63984     True
# 63985    False
# 63986    False
# 63987     True
# 63988     True
# 63989    False
# 63990     True
# 63991     True
# 63992     True
# 63993     True
# 63994    False
# 63995    False
# 63996     True
# ...

# %%
data1[data1.recency<7] #Only takes the dataset for which the Boolean is true
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 1            6    3) $200 - $350   329.08     1       1      Rural       1
# 4            2      1) $0 - $100    45.34     1       0      Urban       0
# 5            6    2) $100 - $200   134.83     0       1  Surburban       0
# 11           1    3) $200 - $350   211.45     0       1      Urban       1
# 12           5    5) $500 - $750   642.90     0       1  Surburban       1
# 13           2    2) $100 - $200   101.64     0       1      Urban       0
# 14           4    3) $200 - $350   241.42     0       1      Rural       1
# 15           3      1) $0 - $100    58.13     1       0      Urban       1
# 16           5      1) $0 - $100    29.99     1       0  Surburban       0
# 19           5  6) $750 - $1,000   828.42     1       0  Surburban       1
# 22           2    2) $100 - $200   118.40     1       0  Surburban       0
# ...

# %%
data1[(data1.recency < 7) & (data1.visit == 1)] #Multiples. Don't use 'and' and 'or'. Use '&' and '|'. Don't forget parentheses!
# Out:
#        recency history_segment  history  mens  womens   zip_code  newbie  \
# 5            6  2) $100 - $200   134.83     0       1  Surburban       0
# 13           2  2) $100 - $200   101.64     0       1      Urban       0
# 15           3    1) $0 - $100    58.13     1       0      Urban       1
# 22           2  2) $100 - $200   118.40     1       0  Surburban       0
# 41           3    1) $0 - $100    99.23     1       0      Rural       0
# 48           3  2) $100 - $200   134.59     1       0      Urban       1
# 81           2    1) $0 - $100    95.33     0       1  Surburban       0
# 87           6  2) $100 - $200   165.77     0       1      Urban       0
# 155          3    1) $0 - $100    57.33     0       1  Surburban       0
# 156          2  3) $200 - $350   289.55     0       1      Rural       0
# 157          5    1) $0 - $100    29.99     0       1  Surburban       1
# 176          3    1) $0 - $100    39.83     0       1      Urban       1
# ...
